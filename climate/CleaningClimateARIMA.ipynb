# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #EDA

# %%
df1 = pd.read_csv('/content/GlobalLandTemperaturesByCity.csv',error_bad_lines=False)

# %%
df1.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_3717500924139848592 = autoviz.get_df('df_3717500924139848592')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
# ...

# %%
i=1
for country in df1['Country'].unique():
  print(i, country)
  i+=1
# Out:
# 1 Denmark
# 2 Turkey
# 3 Kazakhstan
# 4 China
# 5 Spain
# 6 Germany
# 7 Nigeria
# 8 Iran
# 9 Russia
# 10 Canada
# 11 Côte D'Ivoire
# 12 United Kingdom
# 13 Saudi Arabia
# 14 Japan
# 15 United States
# 16 India
# 17 Benin
# 18 United Arab Emirates
# 19 Mexico
# 20 Venezuela
# 21 Ghana
# 22 Ethiopia
# 23 Australia
# 24 Yemen
# 25 Indonesia
# 26 Morocco
# 27 Pakistan
# 28 France
# 29 Libya
# 30 Burma
# 31 Brazil
# 32 South Africa
# 33 Syria
# 34 Egypt
# 35 Algeria
# 36 Netherlands
# 37 Malaysia
# 38 Portugal
# 39 Ecuador
# 40 nan

# %%
ind=df1[df1['Country']=='India']

# %%
ind.head()
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 49880  1816-03-01              19.934                          2.258  Abohar
# 49881  1816-04-01              26.641                          3.398  Abohar
# 49882  1816-05-01              32.535                          2.408  Abohar
# 49883  1816-06-01              33.254                          2.123  Abohar
# 49884  1816-07-01              31.105                          1.848  Abohar
#
#       Country Latitude Longitude
# 49880   India   29.74N    73.85E
# 49881   India   29.74N    73.85E
# 49882   India   29.74N    73.85E
# 49883   India   29.74N    73.85E
# 49884   India   29.74N    73.85E
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_4111633153194436634 = autoviz.get_df('df_4111633153194436634')
#
# ...

# %%
ind.shape
# Out:
# (59615, 7)

# %%
ind.isnull().sum()
# Out:
# dt                                  0
# AverageTemperature               3499
# AverageTemperatureUncertainty    3499
# City                                0
# Country                             0
# Latitude                            0
# Longitude                           0
# dtype: int64

# %%
ind=ind.dropna()

# %%
i=1
for city in ind['City'].unique():
  print(i,'-', city)
  i+=1
# Out:
# 1 - Abohar
# 2 - Achalpur
# 3 - Adilabad
# 4 - Adoni
# 5 - Agartala
# 6 - Agra
# 7 - Ahmadabad
# 8 - Ahmadnagar
# 9 - Aizawl
# 10 - Ajmer
# 11 - Akola
# 12 - Alandur
# 13 - Alappuzha
# 14 - Aligarh
# 15 - Allahabad
# 16 - Alwar
# 17 - Ambala
# 18 - Ambarnath
# 19 - Ambattur
# 20 - Ambur
# 21 - Amravati
# 22 - Amritsar
# 23 - Amroha

# %%
ind.nunique()
# Out:
# dt                                2532
# AverageTemperature               20797
# AverageTemperatureUncertainty     3740
# City                                27
# Country                              1
# Latitude                            13
# Longitude                           22
# dtype: int64

# %% [markdown]
# # creating a dataset for working on ARIMA

# %%
cities = ['Agra', 'Amritsar', 'Allahabad']
df2 = ind[ind['City'].isin(cities)]

# %% [markdown]
# create a new df

# %%
df2.to_csv('cleaned_ClimateData.csv')
