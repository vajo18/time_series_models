# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df_store = pd.read_csv('/content/stores.csv')
df_features = pd.read_csv('/content/features.csv')

# %%
df_train = pd.read_csv('/content/train.csv',error_bad_lines=False)

# %%
print(df_store.shape)
print(df_features.shape)
df_train.shape
# Out:
# (45, 3)
# (8190, 12)
# (421570, 5)

# %%
df_store.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
df_features.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
df_train.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False

# %% [markdown]
# ##Merge datasets

# %%
df = df_train.merge(df_features, on=['Store', 'Date'], how='inner').merge(df_store, on=['Store'], how='inner')
df.head(5)
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday_x  Temperature  \
# 0      1     1  2010-02-05      24924.50        False        42.31
# 1      1     2  2010-02-05      50605.27        False        42.31
# 2      1     3  2010-02-05      13740.12        False        42.31
# 3      1     4  2010-02-05      39954.04        False        42.31
# 4      1     5  2010-02-05      32229.38        False        42.31
#
#    Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 0       2.572        NaN        NaN        NaN        NaN        NaN
# 1       2.572        NaN        NaN        NaN        NaN        NaN
# 2       2.572        NaN        NaN        NaN        NaN        NaN
# 3       2.572        NaN        NaN        NaN        NaN        NaN
# 4       2.572        NaN        NaN        NaN        NaN        NaN
#
#           CPI  Unemployment  IsHoliday_y Type    Size
# 0  211.096358         8.106        False    A  151315
# ...

# %%
df.shape
# Out:
# (421570, 17)

# %% [markdown]
# drop extra holiday column

# %%
df= df.drop('IsHoliday_y', axis=1)

# %%
df.shape
# Out:
# (421570, 16)

# %%
df.nunique()
# Out:
# Store               45
# Dept                81
# Date               143
# Weekly_Sales    359464
# IsHoliday_x          2
# Temperature       3528
# Fuel_Price         892
# MarkDown1         2277
# MarkDown2         1499
# MarkDown3         1662
# MarkDown4         1944
# MarkDown5         2293
# CPI               2145
# Unemployment       349
# Type                 3
# Size                40
# dtype: int64

# %% [markdown]
# remove wrong values

# %%
df.loc[df['Weekly_Sales']<=0]
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday_x  Temperature  \
# 188         1    47  2010-02-19       -863.00        False        39.93
# 406         1    47  2010-03-12       -698.00        False        57.79
# 2549        1    47  2010-10-08        -58.00        False        63.93
# 3632        1    54  2011-01-21        -50.00        False        44.04
# 4132        1    47  2011-03-11          0.00        False        53.56
# ...       ...   ...         ...           ...          ...          ...
# 420066     45    49  2012-05-25         -4.97        False        67.21
# 420403     45    49  2012-06-29        -34.00        False        75.22
# 420736     45    49  2012-08-03         -1.91        False        76.58
# 421007     45    54  2012-08-31          0.00        False        75.09
# 421142     45    49  2012-09-14         -6.83        False        67.87
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# ...

# %%
df = df.loc[df['Weekly_Sales'] > 0]
df.shape
# Out:
# (420212, 16)

# %%
df['Date'].head(5).append(df['Date'].tail(5))
# Out:
# 0         2010-02-05
# 1         2010-02-05
# 2         2010-02-05
# 3         2010-02-05
# 4         2010-02-05
# 421565    2012-10-26
# 421566    2012-10-26
# 421567    2012-10-26
# 421568    2012-10-26
# 421569    2012-10-26
# Name: Date, dtype: object

# %% [markdown]
# data is from 2nd may 2010 to 26th oct 2012

# %% [markdown]
# #Holiday column

# %%
df_holiday = df.loc[df['IsHoliday_x']==True]
df_holiday['Date'].unique()
# Out:
# array(['2010-02-12', '2010-09-10', '2010-11-26', '2010-12-31',
#        '2011-02-11', '2011-09-09', '2011-11-25', '2011-12-30',
#        '2012-02-10', '2012-09-07'], dtype=object)

# %%
df_not_holiday = df.loc[df['IsHoliday_x']==False]
df_not_holiday['Date'].nunique()
# Out:
# 133

# %%
# Super bowl dates in train set
df.loc[(df['Date'] == '2010-02-12')|(df['Date'] == '2011-02-11')|(df['Date'] == '2012-02-10'),'Super_Bowl'] = True
df.loc[(df['Date'] != '2010-02-12')&(df['Date'] != '2011-02-11')&(df['Date'] != '2012-02-10'),'Super_Bowl'] = False

# %%
# Labor day dates in train set
df.loc[(df['Date'] == '2010-09-10')|(df['Date'] == '2011-09-09')|(df['Date'] == '2012-09-07'),'Labor_Day'] = True
df.loc[(df['Date'] != '2010-09-10')&(df['Date'] != '2011-09-09')&(df['Date'] != '2012-09-07'),'Labor_Day'] = False

# %%
# Thanksgiving dates in train set
df.loc[(df['Date'] == '2010-11-26')|(df['Date'] == '2011-11-25'),'Thanksgiving'] = True
df.loc[(df['Date'] != '2010-11-26')&(df['Date'] != '2011-11-25'),'Thanksgiving'] = False

# %%
#New Year dates in train set
df.loc[(df['Date'] == '2010-12-31')|(df['Date'] == '2011-12-30'),'New Year'] = True
df.loc[(df['Date'] != '2010-12-31')&(df['Date'] != '2011-12-30'),'New Year'] = False

# %%
sns.barplot(x='New Year', y='Weekly_Sales', data=df)
# Out:
# <Axes: xlabel='New Year', ylabel='Weekly_Sales'>

# %%
sns.barplot(x='Thanksgiving', y='Weekly_Sales', data=df)
# Out:
# <Axes: xlabel='Thanksgiving', ylabel='Weekly_Sales'>

# %%
sns.barplot(x='Super_Bowl', y='Weekly_Sales', data=df)
# Out:
# <Axes: xlabel='Super_Bowl', ylabel='Weekly_Sales'>

# %%
sns.barplot(x='Labor_Day', y='Weekly_Sales', data=df)
# Out:
# <Axes: xlabel='Labor_Day', ylabel='Weekly_Sales'>

# %%
df= df.drop(['Temperature',	'Fuel_Price',	'MarkDown1',	'MarkDown2',	'MarkDown3','MarkDown4',	'MarkDown5',	'CPI', 'Unemployment'	,'Type'	,'Size'], axis=1)

# %%
df.to_csv('CleanedProductData.csv')
